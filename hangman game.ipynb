# %%
import random
def hangman():
    print("Welcome to Hangman Game")
    words = ["python","maths","apple","excel"]
    word = random.choice(words)
    guessed = ["_"]*len(word)
    attempts = 6
    guessed_letters = []
    while attempts > 0:
        print("\nWord:", " ".join(guessed))
        print("Attempts left:",attempts)
        print("Guessed letters:",guessed_letters)
        guess = input("Enter a letter:").lower()
        if guess in guessed_letters:
            print("You already guessed this letter. Try another!")
            continue
        guessed_letters.append(guess)
        if guess in word:
            print("God job!, Letter found.")
            for i in range(len(word)):
                if word[i]==guess:
                    guessed[i] = guess

            if "_" not in guessed:
                print("Yay!, You guessed the word:",word)
                break

        else:
            print("Wrong guess!")
            attempts -= 1
    if attempts == 0:
        print("\nYou lost! The word was:",word)
hangman()
# Out:
# Welcome to Hangman Game
#
# Word: _ _ _ _ _
# Attempts left: 6
# Guessed letters: []
# Enter a letter: h
# Wrong guess!
#
# Word: _ _ _ _ _
# Attempts left: 5
# Guessed letters: ['h']
# Enter a letter: p
# Wrong guess!
#
# Word: _ _ _ _ _
# Attempts left: 4
# Guessed letters: ['h', 'p']
# Enter a letter: e
# God job!, Letter found.
#
# Word: e _ _ e _
# Attempts left: 4
# Guessed letters: ['h', 'p', 'e']
# Enter a letter: x
# God job!, Letter found.
#
# Word: e x _ e _
# Attempts left: 4
# Guessed letters: ['h', 'p', 'e', 'x']
# Enter a letter: c
# God job!, Letter found.
#
# Word: e x c e _
# Attempts left: 4
# Guessed letters: ['h', 'p', 'e', 'x', 'c']
# Enter a letter: l
# God job!, Letter found.
# Yay!, You guessed the word: excel
